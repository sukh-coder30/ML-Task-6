# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['Species']=df['Species'].map({'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3})

# %%
df['Species']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
df=df.drop('Id', axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        1
# 1              4.9           3.0            1.4           0.2        1
# 2              4.7           3.2            1.3           0.2        1
# 3              4.6           3.1            1.5           0.2        1
# 4              5.0           3.6            1.4           0.2        1
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        3
# 146            6.3           2.5            5.0           1.9        3
# 147            6.5           3.0            5.2           2.0        3
# 148            6.2           3.4            5.4           2.3        3
# 149            5.9           3.0            5.1           1.8        3
#
# [150 rows x 5 columns]

# %%
x=df.drop('Species', axis=1)
y=df['Species']

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %%
#normalizing feature
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scaled= scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=1, stratify=y)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((105, 4), (105,), (45, 4), (45,))

# %%
from sklearn.neighbors import KNeighborsClassifier
#experiment with a different k
k_values=[1, 3, 5, 7]
for k in k_values:
    print(f"\n===k={k} ====")
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
# Out:
# ===k=1 ====
#
# ===k=3 ====
#
# ===k=5 ====
#
# ===k=7 ====

# %%
knn
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred= knn.predict(x_test)

# %%
y_pred
# Out:
# array([3, 1, 1, 2, 2, 2, 3, 2, 3, 1, 1, 3, 1, 2, 1, 2, 3, 2, 2, 3, 3, 1,
#        2, 3, 2, 2, 2, 3, 1, 3, 1, 1, 2, 2, 3, 3, 1, 1, 1, 2, 3, 3, 2, 1,
#        1])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
acc=accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

# %%
acc, cm
# Out:
# (0.9777777777777777,
#  array([[15,  0,  0],
#         [ 0, 15,  0],
#         [ 0,  1, 14]]))

# %%
from sklearn.metrics import ConfusionMatrixDisplay
class_names = ['setosa', 'versicolor', 'virginica']
disp=ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot()
plt.title(f"Confusion Matrix (K={k})")
plt.show()

# %%
#Detailed observations:

#Setosa:

#All 15 samples correctly predicted as Setosa.
#Perfect accuracy for Setosa.

#Versicolor:

#All 15 samples correctly predicted as Versicolor.
#Perfect accuracy for Versicolor.

#Virginica:

#14 predicted correctly as Virginica.

#1 incorrectly predicted as Versicolor.
# 1 misclassification.

#Overall model performance:

#Very high accuracy—only 1 error out of 45 test samples.

#The only confusion is between Virginica and Versicolor, which is common because their measurements overlap more.
